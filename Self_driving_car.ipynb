# %%
# Credits: https://github.com/SullyChen/Autopilot-TensorFlow
# Research paper: End to End Learning for Self-Driving Cars by Nvidia. [https://arxiv.org/pdf/1604.07316.pdf]

# NVidia dataset: 72 hrs of video => 72*60*60*30 = 7,776,000 images
# Nvidia blog: https://devblogs.nvidia.com/deep-learning-self-driving-cars/


# Our Dataset: https://github.com/SullyChen/Autopilot-TensorFlow [https://drive.google.com/file/d/0B-KJCaaF7elleG1RbzVPZWV4Tlk/view]
# Size: 25 minutes = 25*60*30 = 45,000 images ~ 2.3 GB


# If you want to try on a slightly large dataset: 70 minutes of data ~ 223GB
# Refer: https://medium.com/udacity/open-sourcing-223gb-of-mountain-view-driving-data-f6b5593fbfa5
# Format: Image, latitude, longitude, gear, brake, throttle, steering angles and speed



# Additional Installations:
# pip3 install h5py


# AWS: https://aws.amazon.com/blogs/machine-learning/get-started-with-deep-learning-using-the-aws-deep-learning-ami/

# Youtube:https://www.youtube.com/watch?v=qhUvQiKec2U
# Further reading and extensions: https://medium.com/udacity/teaching-a-machine-to-steer-a-car-d73217f2492c
# More data: https://medium.com/udacity/open-sourcing-223gb-of-mountain-view-driving-data-f6b5593fbfa5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read images and steering angles from driving_dataset folder
LIMIT = None
from __future__ import division

import os
import numpy as np
import random

from scipy import pi
from itertools import islice



DATA_FOLDER = '/content/drive/MyDrive/Applied AI dataset uncategorised/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/driving_dataset' # change this to your folder
TRAIN_FILE = os.path.join(DATA_FOLDER, 'data.txt')


split =0.7
X = []
y = []
with open(TRAIN_FILE) as fp:
    for line in islice(fp, LIMIT): #it's same as for line in fp:
        path, angle = line.strip().split()
        full_path = os.path.join(DATA_FOLDER, path)
        X.append(full_path)
        
        # converting angle from degrees to radians
        y.append(float(angle) * pi / 180 )


y = np.array(y)
print("Completed processing data.txt")

split_index = int(len(y)*0.7)

train_y = y[:split_index]
test_y = y[split_index:]
# Out:
# Completed processing data.txt

# %%
import scipy.misc
import random

xs = []
ys = []

#points to the end of the last batch
train_batch_pointer = 0
val_batch_pointer = 0

#read data.txt
with open("/content/drive/MyDrive/Applied AI dataset uncategorised/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/driving_dataset/data.txt") as f:
    for line in f:
        xs.append("/content/drive/MyDrive/Applied AI dataset uncategorised/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/driving_dataset/" + line.split()[0])
        #the paper by Nvidia uses the inverse of the turning radius,
        #but steering wheel angle is proportional to the inverse of turning radius
        #so the steering wheel angle in radians is used as the output
        ys.append(float(line.split()[1]) * scipy.pi / 180)

#get number of images
num_images = len(xs)


train_xs = xs[:int(len(xs) * 0.7)]
train_ys = ys[:int(len(xs) * 0.7)]

val_xs = xs[-int(len(xs) * 0.3):]
val_ys = ys[-int(len(xs) * 0.3):]

num_train_images = len(train_xs)
num_val_images = len(val_xs)

def LoadTrainBatch(batch_size):
    global train_batch_pointer
    x_out = []
    y_out = []
    for i in range(0, batch_size):
        x_out.append(scipy.misc.imresize(scipy.misc.imread(train_xs[(train_batch_pointer + i) % num_train_images])[-150:], [66, 200]) / 255.0)
        y_out.append([train_ys[(train_batch_pointer + i) % num_train_images]])
    train_batch_pointer += batch_size
    return x_out, y_out

def LoadValBatch(batch_size):
    global val_batch_pointer
    x_out = []
    y_out = []
    for i in range(0, batch_size):
        x_out.append(scipy.misc.imresize(scipy.misc.imread(val_xs[(val_batch_pointer + i) % num_val_images])[-150:], [66, 200]) / 255.0)
        y_out.append([val_ys[(val_batch_pointer + i) % num_val_images]])
    val_batch_pointer += batch_size
    return x_out, y_out

# %%
pip uninstall scipy
# Out:
# Uninstalling scipy-1.3.3:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/scipy-1.3.3.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/scipy/*
# Proceed (y/n)? y
#   Successfully uninstalled scipy-1.3.3

# %%
pip install scipy==1.2.2
# Out:
# Collecting scipy==1.2.2
#   Downloading https://files.pythonhosted.org/packages/83/69/20c8f3b7efe362093dff891239551ff90d4c463b5f52676e2694fea09442/scipy-1.2.2-cp36-cp36m-manylinux1_x86_64.whl (24.8MB)
#      |████████████████████████████████| 24.8MB 378kB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.2.2) (1.17.4)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
# Successfully installed scipy-1.2.2

# %%
# scipy.misc.imresize(scipy.misc.imread(train_xs[(train_batch_pointer + i) % num_train_images])[-150:], [66, 200]) / 255.0
# you can break the whole line into parts like this
# here (train_batch_pointer + i) % num_train_images => "% num_train_images" is used to make sure that the
# (train_batch_pointer + i) values should not cross number of train images.
import imageio
# lets explain whats happening with the first images
#import scipy.misc.imresize
image_read = imageio.imread(train_xs[0])
print("original image size",image_read.shape)

print("After taking the last 150 rows i.e lower part of the images where road is present, ",image_read[-150:].shape)
image_read = image_read[-150:]
resized_image = scipy.misc.imresize(image_read, [66, 200])
print("After resizing the images into 66*200, ",resized_image.shape)
# 200/66 = 455/150 = 3.0303 => we are keeping aspect ratio when we are resizing it
# Out:
# original image size (256, 455, 3)
# After taking the last 150 rows i.e lower part of the images where road is present,  (150, 455, 3)
# After resizing the images into 66*200,  (66, 200, 3)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   if __name__ == '__main__':

# %%
#scipy.misc.imresize(scipy.misc.imread(train_xs[0])[-150:], [66, 200])

# %%
#xs

# %%
import tensorflow as tf
import scipy

def weight_variable(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

def conv2d(x, W, stride):
  return tf.nn.conv2d(x, W, strides=[1, stride, stride, 1], padding='VALID')

x = tf.placeholder(tf.float32, shape=[None, 66, 200, 3])
y_ = tf.placeholder(tf.float32, shape=[None, 1])

x_image = x

#first convolutional layer
W_conv1 = weight_variable([5, 5, 3, 24])
b_conv1 = bias_variable([24])

h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1, 2) + b_conv1)

#second convolutional layer
W_conv2 = weight_variable([5, 5, 24, 36])
b_conv2 = bias_variable([36])

h_conv2 = tf.nn.relu(conv2d(h_conv1, W_conv2, 2) + b_conv2)

#third convolutional layer
W_conv3 = weight_variable([5, 5, 36, 48])
b_conv3 = bias_variable([48])

h_conv3 = tf.nn.relu(conv2d(h_conv2, W_conv3, 2) + b_conv3)

#fourth convolutional layer
W_conv4 = weight_variable([3, 3, 48, 64])
b_conv4 = bias_variable([64])

h_conv4 = tf.nn.relu(conv2d(h_conv3, W_conv4, 1) + b_conv4)

#fifth convolutional layer
W_conv5 = weight_variable([3, 3, 64, 64])
b_conv5 = bias_variable([64])

h_conv5 = tf.nn.relu(conv2d(h_conv4, W_conv5, 1) + b_conv5)

#FCL 1
W_fc1 = weight_variable([1152, 1164])
b_fc1 = bias_variable([1164])

h_conv5_flat = tf.reshape(h_conv5, [-1, 1152])
h_fc1 = tf.nn.relu(tf.matmul(h_conv5_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

#FCL 2
W_fc2 = weight_variable([1164, 100])
b_fc2 = bias_variable([100])

h_fc2 = tf.nn.relu(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)

h_fc2_drop = tf.nn.dropout(h_fc2, keep_prob)

#FCL 3
W_fc3 = weight_variable([100, 50])
b_fc3 = bias_variable([50])

h_fc3 = tf.nn.relu(tf.matmul(h_fc2_drop, W_fc3) + b_fc3)

h_fc3_drop = tf.nn.dropout(h_fc3, keep_prob)

#FCL 3
W_fc4 = weight_variable([50, 10])
b_fc4 = bias_variable([10])

h_fc4 = tf.nn.relu(tf.matmul(h_fc3_drop, W_fc4) + b_fc4)

h_fc4_drop = tf.nn.dropout(h_fc4, keep_prob)

#Output
W_fc5 = weight_variable([10, 1])
b_fc5 = bias_variable([1])

# #scale the atan output
#y = tf.multiply(tf.atan(tf.matmul(h_fc4_drop, W_fc5) + b_fc5), 2)

y = tf.matmul(h_fc4_drop, W_fc5) + b_fc5 #final layer as linear unit
#print(y)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From <ipython-input-4-85ac33d76437>:58: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
Tensor("add_30:0", shape=(?, 1), dtype=float32)

# %%
'''d=[]
while(1):
  d.append('1')
  '''

# %%
import numpy;

# PDF of train and test 'y' values. 
import matplotlib.pyplot as plt 
plt.hist(train_y, bins=50, normed=1, color='green', histtype ='step');
plt.hist(test_y, bins=50, normed=1, color='red', histtype ='step');
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %%
#Model 0: Base line Model: y_test_pred = mean(y_train_i) 
train_mean_y = np.mean(train_y)

print('Test_MSE(MEAN):%f' % np.mean(np.square(test_y-train_mean_y)) )

print('Test_MSE(ZERO):%f' % np.mean(np.square(test_y-0.0)) )
# Out:
# Test_MSE(MEAN):0.241561
# Test_MSE(ZERO):0.241107

# %%
import os
import tensorflow as tf
from tensorflow.core.protobuf import saver_pb2
#import driving_data
#import model

LOGDIR = '/content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/testing2'

sess = tf.InteractiveSession()

L2NormConst = 0.001

train_vars = tf.trainable_variables()

loss = tf.reduce_mean(tf.square(tf.subtract(y_, y))) + tf.add_n([tf.nn.l2_loss(v) for v in train_vars]) * L2NormConst
train_step = tf.train.AdamOptimizer(1e-4).minimize(loss)
sess.run(tf.initialize_all_variables())

# create a summary to monitor cost tensor
tf.summary.scalar("loss", loss)
# merge all summaries into a single op
merged_summary_op =  tf.summary.merge_all()

saver = tf.train.Saver(write_version = saver_pb2.SaverDef.V1)

# op to write logs to Tensorboard
logs_path = '/content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/logs'
summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())

epochs = 10
batch_size = 100

# train over the dataset about 30 times
for epoch in range(epochs):
  for i in range(int(num_images/batch_size)):
    xs, ys = LoadTrainBatch(batch_size)
    train_step.run(feed_dict={x: xs, y_: ys, keep_prob: 0.5})
    if i % 10 == 0:
      xs, ys = LoadValBatch(batch_size)
      loss_value = loss.eval(feed_dict={x:xs, y_: ys, keep_prob: 0.5})
      print("Epoch: %d, Step: %d, Loss: %g" % (epoch, epoch * batch_size + i, loss_value))

    # write logs at every iteration
    summary = merged_summary_op.eval(feed_dict={x:xs, y_: ys, keep_prob: 0.5})
    summary_writer.add_summary(summary, epoch * num_images/batch_size + i)

    if i % batch_size == 0:
      if not os.path.exists(LOGDIR):
        os.makedirs(LOGDIR)
      checkpoint_path = os.path.join(LOGDIR, "model5.ckpt")
      filename = saver.save(sess, checkpoint_path)
  print("Model saved in file: %s" % filename)

print("Run the command line:\n" \
          "--> tensorboard --logdir=./logs " \
          "\nThen open http://0.0.0.0:6006/ into your web browser")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/tf_should_use.py:198: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
# Epoch: 0, Step: 0, Loss: 9.12093
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 0, Step: 10, Loss: 6.67136
# Epoch: 0, Step: 20, Loss: 6.2942
# Epoch: 0, Step: 30, Loss: 6.23819
# Epoch: 0, Step: 40, Loss: 6.38521
# Epoch: 0, Step: 50, Loss: 6.10843
# Epoch: 0, Step: 60, Loss: 6.19433
# Epoch: 0, Step: 70, Loss: 6.33499
# Epoch: 0, Step: 80, Loss: 6.23385
# Epoch: 0, Step: 90, Loss: 5.89648
# Epoch: 0, Step: 100, Loss: 5.85154
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 0, Step: 110, Loss: 5.80677
# Epoch: 0, Step: 120, Loss: 5.76618
# Epoch: 0, Step: 130, Loss: 6.03653
# Epoch: 0, Step: 140, Loss: 6.44226
# Epoch: 0, Step: 150, Loss: 5.94998
# Epoch: 0, Step: 160, Loss: 6.48314
# Epoch: 0, Step: 170, Loss: 5.87959
# Epoch: 0, Step: 180, Loss: 6.12254
# Epoch: 0, Step: 190, Loss: 5.82208
# Epoch: 0, Step: 200, Loss: 5.46
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 0, Step: 210, Loss: 5.43012
# Epoch: 0, Step: 220, Loss: 5.41381
# Epoch: 0, Step: 230, Loss: 5.47563
# Epoch: 0, Step: 240, Loss: 6.38403
# Epoch: 0, Step: 250, Loss: 5.44525
# Epoch: 0, Step: 260, Loss: 7.2922
# Epoch: 0, Step: 270, Loss: 5.78024
# Epoch: 0, Step: 280, Loss: 6.33172
# Epoch: 0, Step: 290, Loss: 5.22327
# Epoch: 0, Step: 300, Loss: 5.10529
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 0, Step: 310, Loss: 5.26719
# Epoch: 0, Step: 320, Loss: 6.32694
# Epoch: 0, Step: 330, Loss: 5.5216
# Epoch: 0, Step: 340, Loss: 5.13043
# Epoch: 0, Step: 350, Loss: 4.96957
# Epoch: 0, Step: 360, Loss: 4.97594
# Epoch: 0, Step: 370, Loss: 5.21202
# Epoch: 0, Step: 380, Loss: 5.11904
# Epoch: 0, Step: 390, Loss: 6.18223
# Epoch: 0, Step: 400, Loss: 5.57389
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 0, Step: 410, Loss: 4.78996
# Epoch: 0, Step: 420, Loss: 4.74489
# Epoch: 0, Step: 430, Loss: 4.73588
# Epoch: 0, Step: 440, Loss: 4.71663
# Epoch: 0, Step: 450, Loss: 4.71955
# Model saved in file: /content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/testing2/model5.ckpt
# Epoch: 1, Step: 100, Loss: 5.14231
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 1, Step: 110, Loss: 5.03067
# Epoch: 1, Step: 120, Loss: 4.69307
# Epoch: 1, Step: 130, Loss: 4.56556
# Epoch: 1, Step: 140, Loss: 4.52704
# Epoch: 1, Step: 150, Loss: 4.55918
# Epoch: 1, Step: 160, Loss: 4.88361
# Epoch: 1, Step: 170, Loss: 5.96558
# Epoch: 1, Step: 180, Loss: 5.16744
# Epoch: 1, Step: 190, Loss: 4.45326
# Epoch: 1, Step: 200, Loss: 4.37564
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 1, Step: 210, Loss: 4.33019
# Epoch: 1, Step: 220, Loss: 4.29833
# Epoch: 1, Step: 230, Loss: 4.27957
# Epoch: 1, Step: 240, Loss: 4.29134
# Epoch: 1, Step: 250, Loss: 4.28907
# Epoch: 1, Step: 260, Loss: 4.1927
# Epoch: 1, Step: 270, Loss: 4.21946
# Epoch: 1, Step: 280, Loss: 4.2578
# Epoch: 1, Step: 290, Loss: 4.46667
# Epoch: 1, Step: 300, Loss: 4.26667
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 1, Step: 310, Loss: 4.07517
# Epoch: 1, Step: 320, Loss: 4.04632
# Epoch: 1, Step: 330, Loss: 4.022
# Epoch: 1, Step: 340, Loss: 3.99373
# Epoch: 1, Step: 350, Loss: 3.9724
# Epoch: 1, Step: 360, Loss: 5.76765
# Epoch: 1, Step: 370, Loss: 7.84169
# Epoch: 1, Step: 380, Loss: 3.90373
# Epoch: 1, Step: 390, Loss: 3.87284
# Epoch: 1, Step: 400, Loss: 3.8483
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 1, Step: 410, Loss: 3.82782
# Epoch: 1, Step: 420, Loss: 3.80368
# Epoch: 1, Step: 430, Loss: 3.78318
# Epoch: 1, Step: 440, Loss: 3.76236
# Epoch: 1, Step: 450, Loss: 3.74069
# Epoch: 1, Step: 460, Loss: 3.72016
# Epoch: 1, Step: 470, Loss: 3.6914
# Epoch: 1, Step: 480, Loss: 3.6741
# Epoch: 1, Step: 490, Loss: 3.66848
# Epoch: 1, Step: 500, Loss: 3.64682
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 1, Step: 510, Loss: 3.60842
# Epoch: 1, Step: 520, Loss: 3.58253
# Epoch: 1, Step: 530, Loss: 3.56069
# Epoch: 1, Step: 540, Loss: 3.54022
# Epoch: 1, Step: 550, Loss: 3.51861
# Model saved in file: /content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/testing2/model5.ckpt
# Epoch: 2, Step: 200, Loss: 3.51252
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 2, Step: 210, Loss: 3.48862
# Epoch: 2, Step: 220, Loss: 3.46919
# Epoch: 2, Step: 230, Loss: 3.45112
# Epoch: 2, Step: 240, Loss: 3.42905
# Epoch: 2, Step: 250, Loss: 3.4118
# Epoch: 2, Step: 260, Loss: 3.39171
# Epoch: 2, Step: 270, Loss: 3.37103
# Epoch: 2, Step: 280, Loss: 3.35275
# Epoch: 2, Step: 290, Loss: 3.33363
# Epoch: 2, Step: 300, Loss: 3.36004
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 2, Step: 310, Loss: 3.31607
# Epoch: 2, Step: 320, Loss: 7.38596
# Epoch: 2, Step: 330, Loss: 4.86748
# Epoch: 2, Step: 340, Loss: 3.23529
# Epoch: 2, Step: 350, Loss: 3.22054
# Epoch: 2, Step: 360, Loss: 3.2348
# Epoch: 2, Step: 370, Loss: 3.23522
# Epoch: 2, Step: 380, Loss: 3.17013
# Epoch: 2, Step: 390, Loss: 3.23429
# Epoch: 2, Step: 400, Loss: 3.23602
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 2, Step: 410, Loss: 3.10378
# Epoch: 2, Step: 420, Loss: 3.13489
# Epoch: 2, Step: 430, Loss: 3.07828
# Epoch: 2, Step: 440, Loss: 3.0661
# Epoch: 2, Step: 450, Loss: 3.03798
# Epoch: 2, Step: 460, Loss: 3.11579
# Epoch: 2, Step: 470, Loss: 3.04248
# Epoch: 2, Step: 480, Loss: 3.12916
# Epoch: 2, Step: 490, Loss: 3.08017
# Epoch: 2, Step: 500, Loss: 2.96308
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 2, Step: 510, Loss: 2.93782
# Epoch: 2, Step: 520, Loss: 2.92037
# Epoch: 2, Step: 530, Loss: 2.90364
# Epoch: 2, Step: 540, Loss: 2.886
# Epoch: 2, Step: 550, Loss: 2.87331
# Epoch: 2, Step: 560, Loss: 2.85611
# Epoch: 2, Step: 570, Loss: 2.83716
# Epoch: 2, Step: 580, Loss: 2.83107
# Epoch: 2, Step: 590, Loss: 2.80961
# Epoch: 2, Step: 600, Loss: 2.7922
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 2, Step: 610, Loss: 2.77401
# Epoch: 2, Step: 620, Loss: 2.78528
# Epoch: 2, Step: 630, Loss: 2.77354
# Epoch: 2, Step: 640, Loss: 3.0638
# Epoch: 2, Step: 650, Loss: 2.7182
# Model saved in file: /content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/testing2/model5.ckpt
# Epoch: 3, Step: 300, Loss: 2.74559
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 3, Step: 310, Loss: 2.7597
# Epoch: 3, Step: 320, Loss: 3.01304
# Epoch: 3, Step: 330, Loss: 2.72178
# Epoch: 3, Step: 340, Loss: 2.72117
# Epoch: 3, Step: 350, Loss: 2.93852
# Epoch: 3, Step: 360, Loss: 2.90535
# Epoch: 3, Step: 370, Loss: 2.60675
# Epoch: 3, Step: 380, Loss: 2.63215
# Epoch: 3, Step: 390, Loss: 2.57321
# Epoch: 3, Step: 400, Loss: 2.58635
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 3, Step: 410, Loss: 2.62222
# Epoch: 3, Step: 420, Loss: 3.44198
# Epoch: 3, Step: 430, Loss: 2.67413
# Epoch: 3, Step: 440, Loss: 3.37501
# Epoch: 3, Step: 450, Loss: 2.99891
# Epoch: 3, Step: 460, Loss: 2.92147
# Epoch: 3, Step: 470, Loss: 2.90212
# Epoch: 3, Step: 480, Loss: 2.4654
# Epoch: 3, Step: 490, Loss: 2.4348
# Epoch: 3, Step: 500, Loss: 2.44247
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 3, Step: 510, Loss: 2.55108
# Epoch: 3, Step: 520, Loss: 3.21542
# Epoch: 3, Step: 530, Loss: 2.70763
# Epoch: 3, Step: 540, Loss: 4.15697
# Epoch: 3, Step: 550, Loss: 3.00124
# Epoch: 3, Step: 560, Loss: 3.50667
# Epoch: 3, Step: 570, Loss: 2.55163
# Epoch: 3, Step: 580, Loss: 2.31148
# Epoch: 3, Step: 590, Loss: 2.38527
# Epoch: 3, Step: 600, Loss: 3.4072
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 3, Step: 610, Loss: 3.0696
# Epoch: 3, Step: 620, Loss: 2.36574
# Epoch: 3, Step: 630, Loss: 2.30492
# Epoch: 3, Step: 640, Loss: 2.27802
# Epoch: 3, Step: 650, Loss: 2.62353
# Epoch: 3, Step: 660, Loss: 2.37717
# Epoch: 3, Step: 670, Loss: 3.24115
# Epoch: 3, Step: 680, Loss: 3.07034
# Epoch: 3, Step: 690, Loss: 2.31755
# Epoch: 3, Step: 700, Loss: 2.16976
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 3, Step: 710, Loss: 2.16923
# Epoch: 3, Step: 720, Loss: 2.16825
# Epoch: 3, Step: 730, Loss: 2.16532
# Epoch: 3, Step: 740, Loss: 2.58965
# Epoch: 3, Step: 750, Loss: 2.64255
# Model saved in file: /content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/testing2/model5.ckpt
# Epoch: 4, Step: 400, Loss: 2.25883
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 4, Step: 410, Loss: 2.11345
# Epoch: 4, Step: 420, Loss: 2.09409
# Epoch: 4, Step: 430, Loss: 2.09245
# Epoch: 4, Step: 440, Loss: 2.27704
# Epoch: 4, Step: 450, Loss: 3.38946
# Epoch: 4, Step: 460, Loss: 3.0699
# Epoch: 4, Step: 470, Loss: 2.06283
# Epoch: 4, Step: 480, Loss: 2.06751
# Epoch: 4, Step: 490, Loss: 1.99816
# Epoch: 4, Step: 500, Loss: 1.99026
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 4, Step: 510, Loss: 1.98127
# Epoch: 4, Step: 520, Loss: 1.99142
# Epoch: 4, Step: 530, Loss: 2.02446
# Epoch: 4, Step: 540, Loss: 1.95142
# Epoch: 4, Step: 550, Loss: 1.95386
# Epoch: 4, Step: 560, Loss: 2.03342
# Epoch: 4, Step: 570, Loss: 2.27966
# Epoch: 4, Step: 580, Loss: 2.09888
# Epoch: 4, Step: 590, Loss: 1.89937
# Epoch: 4, Step: 600, Loss: 1.88365
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 4, Step: 610, Loss: 1.87418
# Epoch: 4, Step: 620, Loss: 1.86488
# Epoch: 4, Step: 630, Loss: 1.85435
# Epoch: 4, Step: 640, Loss: 2.37729
# Epoch: 4, Step: 650, Loss: 6.81742
# Epoch: 4, Step: 660, Loss: 1.86522
# Epoch: 4, Step: 670, Loss: 1.81671
# Epoch: 4, Step: 680, Loss: 1.80182
# Epoch: 4, Step: 690, Loss: 1.79625
# Epoch: 4, Step: 700, Loss: 1.78508
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 4, Step: 710, Loss: 1.7731
# Epoch: 4, Step: 720, Loss: 1.76634
# Epoch: 4, Step: 730, Loss: 1.75524
# Epoch: 4, Step: 740, Loss: 1.74706
# Epoch: 4, Step: 750, Loss: 1.73673
# Epoch: 4, Step: 760, Loss: 1.73032
# Epoch: 4, Step: 770, Loss: 1.73492
# Epoch: 4, Step: 780, Loss: 1.7284
# Epoch: 4, Step: 790, Loss: 1.70773
# Epoch: 4, Step: 800, Loss: 1.68967
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 4, Step: 810, Loss: 1.67902
# Epoch: 4, Step: 820, Loss: 1.67135
# Epoch: 4, Step: 830, Loss: 1.66475
# Epoch: 4, Step: 840, Loss: 1.65457
# Epoch: 4, Step: 850, Loss: 1.64756
# Model saved in file: /content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/testing2/model5.ckpt
# Epoch: 5, Step: 500, Loss: 1.64449
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 5, Step: 510, Loss: 1.63868
# Epoch: 5, Step: 520, Loss: 1.62689
# Epoch: 5, Step: 530, Loss: 1.619
# Epoch: 5, Step: 540, Loss: 1.60766
# Epoch: 5, Step: 550, Loss: 1.60094
# Epoch: 5, Step: 560, Loss: 1.58981
# Epoch: 5, Step: 570, Loss: 1.58153
# Epoch: 5, Step: 580, Loss: 1.58511
# Epoch: 5, Step: 590, Loss: 1.62016
# Epoch: 5, Step: 600, Loss: 4.36854
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 5, Step: 610, Loss: 4.3448
# Epoch: 5, Step: 620, Loss: 1.54071
# Epoch: 5, Step: 630, Loss: 1.53016
# Epoch: 5, Step: 640, Loss: 1.57279
# Epoch: 5, Step: 650, Loss: 1.56522
# Epoch: 5, Step: 660, Loss: 1.54785
# Epoch: 5, Step: 670, Loss: 1.55353
# Epoch: 5, Step: 680, Loss: 1.61414
# Epoch: 5, Step: 690, Loss: 1.48237
# Epoch: 5, Step: 700, Loss: 1.50626
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 5, Step: 710, Loss: 1.49077
# Epoch: 5, Step: 720, Loss: 1.47818
# Epoch: 5, Step: 730, Loss: 1.45897
# Epoch: 5, Step: 740, Loss: 1.5256
# Epoch: 5, Step: 750, Loss: 1.50029
# Epoch: 5, Step: 760, Loss: 1.51152
# Epoch: 5, Step: 770, Loss: 1.52205
# Epoch: 5, Step: 780, Loss: 1.4426
# Epoch: 5, Step: 790, Loss: 1.4266
# Epoch: 5, Step: 800, Loss: 1.4037
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 5, Step: 810, Loss: 1.39522
# Epoch: 5, Step: 820, Loss: 1.38684
# Epoch: 5, Step: 830, Loss: 1.37879
# Epoch: 5, Step: 840, Loss: 1.37609
# Epoch: 5, Step: 850, Loss: 1.36694
# Epoch: 5, Step: 860, Loss: 1.37148
# Epoch: 5, Step: 870, Loss: 1.35621
# Epoch: 5, Step: 880, Loss: 1.34896
# Epoch: 5, Step: 890, Loss: 1.33609
# Epoch: 5, Step: 900, Loss: 1.35467
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 5, Step: 910, Loss: 1.3751
# Epoch: 5, Step: 920, Loss: 1.60287
# Epoch: 5, Step: 930, Loss: 1.34609
# Epoch: 5, Step: 940, Loss: 1.33931
# Epoch: 5, Step: 950, Loss: 1.39483
# Model saved in file: /content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/testing2/model5.ckpt
# Epoch: 6, Step: 600, Loss: 1.57154
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 6, Step: 610, Loss: 1.46121
# Epoch: 6, Step: 620, Loss: 1.30361
# Epoch: 6, Step: 630, Loss: 1.53452
# Epoch: 6, Step: 640, Loss: 1.5854
# Epoch: 6, Step: 650, Loss: 1.26882
# Epoch: 6, Step: 660, Loss: 1.29715
# Epoch: 6, Step: 670, Loss: 1.24461
# Epoch: 6, Step: 680, Loss: 1.27728
# Epoch: 6, Step: 690, Loss: 1.24928
# Epoch: 6, Step: 700, Loss: 1.99494
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 6, Step: 710, Loss: 1.39579
# Epoch: 6, Step: 720, Loss: 1.96252
# Epoch: 6, Step: 730, Loss: 1.86013
# Epoch: 6, Step: 740, Loss: 1.45703
# Epoch: 6, Step: 750, Loss: 1.72427
# Epoch: 6, Step: 760, Loss: 1.29413
# Epoch: 6, Step: 770, Loss: 1.18709
# Epoch: 6, Step: 780, Loss: 1.19385
# Epoch: 6, Step: 790, Loss: 1.30467
# Epoch: 6, Step: 800, Loss: 1.64032
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 6, Step: 810, Loss: 1.86769
# Epoch: 6, Step: 820, Loss: 2.38811
# Epoch: 6, Step: 830, Loss: 2.27011
# Epoch: 6, Step: 840, Loss: 2.14843
# Epoch: 6, Step: 850, Loss: 1.54672
# Epoch: 6, Step: 860, Loss: 1.12484
# Epoch: 6, Step: 870, Loss: 1.15245
# Epoch: 6, Step: 880, Loss: 2.00717
# Epoch: 6, Step: 890, Loss: 2.27972
# Epoch: 6, Step: 900, Loss: 1.16053
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 6, Step: 910, Loss: 1.18353
# Epoch: 6, Step: 920, Loss: 1.10499
# Epoch: 6, Step: 930, Loss: 1.38226
# Epoch: 6, Step: 940, Loss: 1.28719
# Epoch: 6, Step: 950, Loss: 1.88985
# Epoch: 6, Step: 960, Loss: 2.11442
# Epoch: 6, Step: 970, Loss: 1.31074
# Epoch: 6, Step: 980, Loss: 1.06059
# Epoch: 6, Step: 990, Loss: 1.06728
# Epoch: 6, Step: 1000, Loss: 1.06515
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 6, Step: 1010, Loss: 1.07813
# Epoch: 6, Step: 1020, Loss: 1.36849
# Epoch: 6, Step: 1030, Loss: 1.56507
# Epoch: 6, Step: 1040, Loss: 1.23737
# Epoch: 6, Step: 1050, Loss: 1.07553
# Model saved in file: /content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/testing2/model5.ckpt
# Epoch: 7, Step: 700, Loss: 1.05406
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 7, Step: 710, Loss: 1.02942
# Epoch: 7, Step: 720, Loss: 1.19814
# Epoch: 7, Step: 730, Loss: 2.08452
# Epoch: 7, Step: 740, Loss: 2.31247
# Epoch: 7, Step: 750, Loss: 1.08545
# Epoch: 7, Step: 760, Loss: 1.05634
# Epoch: 7, Step: 770, Loss: 0.981085
# Epoch: 7, Step: 780, Loss: 0.989659
# Epoch: 7, Step: 790, Loss: 0.977617
# Epoch: 7, Step: 800, Loss: 0.985146
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 7, Step: 810, Loss: 0.996772
# Epoch: 7, Step: 820, Loss: 0.985327
# Epoch: 7, Step: 830, Loss: 0.958916
# Epoch: 7, Step: 840, Loss: 1.04769
# Epoch: 7, Step: 850, Loss: 1.34837
# Epoch: 7, Step: 860, Loss: 1.06026
# Epoch: 7, Step: 870, Loss: 1.04347
# Epoch: 7, Step: 880, Loss: 0.935356
# Epoch: 7, Step: 890, Loss: 0.930333
# Epoch: 7, Step: 900, Loss: 0.924917
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 7, Step: 910, Loss: 0.920155
# Epoch: 7, Step: 920, Loss: 0.964244
# Epoch: 7, Step: 930, Loss: 6.16465
# Epoch: 7, Step: 940, Loss: 1.09424
# Epoch: 7, Step: 950, Loss: 0.902298
# Epoch: 7, Step: 960, Loss: 0.890593
# Epoch: 7, Step: 970, Loss: 0.890676
# Epoch: 7, Step: 980, Loss: 0.888899
# Epoch: 7, Step: 990, Loss: 0.886609
# Epoch: 7, Step: 1000, Loss: 0.901644
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 7, Step: 1010, Loss: 0.882158
# Epoch: 7, Step: 1020, Loss: 0.879086
# Epoch: 7, Step: 1030, Loss: 0.898849
# Epoch: 7, Step: 1040, Loss: 1.05507
# Epoch: 7, Step: 1050, Loss: 0.864785
# Epoch: 7, Step: 1060, Loss: 0.860037
# Epoch: 7, Step: 1070, Loss: 0.855597
# Epoch: 7, Step: 1080, Loss: 0.844245
# Epoch: 7, Step: 1090, Loss: 0.834633
# Epoch: 7, Step: 1100, Loss: 0.832619
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 7, Step: 1110, Loss: 0.82807
# Epoch: 7, Step: 1120, Loss: 0.823008
# Epoch: 7, Step: 1130, Loss: 0.818971
# Epoch: 7, Step: 1140, Loss: 0.81057
# Epoch: 7, Step: 1150, Loss: 0.80887
# Model saved in file: /content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/testing2/model5.ckpt
# Epoch: 8, Step: 800, Loss: 0.808413
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 8, Step: 810, Loss: 0.802125
# Epoch: 8, Step: 820, Loss: 0.796916
# Epoch: 8, Step: 830, Loss: 0.793513
# Epoch: 8, Step: 840, Loss: 0.789151
# Epoch: 8, Step: 850, Loss: 0.78497
# Epoch: 8, Step: 860, Loss: 0.785282
# Epoch: 8, Step: 870, Loss: 0.839621
# Epoch: 8, Step: 880, Loss: 2.21487
# Epoch: 8, Step: 890, Loss: 4.81585
# Epoch: 8, Step: 900, Loss: 0.770695
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 8, Step: 910, Loss: 0.761094
# Epoch: 8, Step: 920, Loss: 0.802472
# Epoch: 8, Step: 930, Loss: 0.804009
# Epoch: 8, Step: 940, Loss: 0.797866
# Epoch: 8, Step: 950, Loss: 0.77136
# Epoch: 8, Step: 960, Loss: 0.898865
# Epoch: 8, Step: 970, Loss: 0.751901
# Epoch: 8, Step: 980, Loss: 0.748145
# Epoch: 8, Step: 990, Loss: 0.785113
# Epoch: 8, Step: 1000, Loss: 0.771513
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 8, Step: 1010, Loss: 0.736384
# Epoch: 8, Step: 1020, Loss: 0.774783
# Epoch: 8, Step: 1030, Loss: 0.784283
# Epoch: 8, Step: 1040, Loss: 0.817492
# Epoch: 8, Step: 1050, Loss: 0.854245
# Epoch: 8, Step: 1060, Loss: 0.7348
# Epoch: 8, Step: 1070, Loss: 0.722311
# Epoch: 8, Step: 1080, Loss: 0.706746
# Epoch: 8, Step: 1090, Loss: 0.702663
# Epoch: 8, Step: 1100, Loss: 0.70275
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 8, Step: 1110, Loss: 0.702186
# Epoch: 8, Step: 1120, Loss: 0.693497
# Epoch: 8, Step: 1130, Loss: 0.69333
# Epoch: 8, Step: 1140, Loss: 0.701596
# Epoch: 8, Step: 1150, Loss: 0.693527
# Epoch: 8, Step: 1160, Loss: 0.692102
# Epoch: 8, Step: 1170, Loss: 0.672867
# Epoch: 8, Step: 1180, Loss: 0.680962
# Epoch: 8, Step: 1190, Loss: 0.732773
# Epoch: 8, Step: 1200, Loss: 0.843748
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 8, Step: 1210, Loss: 0.794638
# Epoch: 8, Step: 1220, Loss: 0.676198
# Epoch: 8, Step: 1230, Loss: 0.73922
# Epoch: 8, Step: 1240, Loss: 0.840534
# Epoch: 8, Step: 1250, Loss: 0.909593
# Model saved in file: /content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/testing2/model5.ckpt
# Epoch: 9, Step: 900, Loss: 0.649926
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 9, Step: 910, Loss: 0.794461
# Epoch: 9, Step: 920, Loss: 0.873542
# Epoch: 9, Step: 930, Loss: 0.662599
# Epoch: 9, Step: 940, Loss: 0.683038
# Epoch: 9, Step: 950, Loss: 0.630397
# Epoch: 9, Step: 960, Loss: 0.639922
# Epoch: 9, Step: 970, Loss: 0.658197
# Epoch: 9, Step: 980, Loss: 1.21447
# Epoch: 9, Step: 990, Loss: 0.923243
# Epoch: 9, Step: 1000, Loss: 1.15542
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 9, Step: 1010, Loss: 1.34966
# Epoch: 9, Step: 1020, Loss: 0.752225
# Epoch: 9, Step: 1030, Loss: 1.22118
# Epoch: 9, Step: 1040, Loss: 0.737084
# Epoch: 9, Step: 1050, Loss: 0.601339
# Epoch: 9, Step: 1060, Loss: 0.608605
# Epoch: 9, Step: 1070, Loss: 0.718738
# Epoch: 9, Step: 1080, Loss: 0.80134
# Epoch: 9, Step: 1090, Loss: 1.35939
# Epoch: 9, Step: 1100, Loss: 1.3267
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 9, Step: 1110, Loss: 2.34488
# Epoch: 9, Step: 1120, Loss: 1.21969
# Epoch: 9, Step: 1130, Loss: 1.12531
# Epoch: 9, Step: 1140, Loss: 0.575055
# Epoch: 9, Step: 1150, Loss: 0.5798
# Epoch: 9, Step: 1160, Loss: 1.24457
# Epoch: 9, Step: 1170, Loss: 1.98732
# Epoch: 9, Step: 1180, Loss: 0.62526
# Epoch: 9, Step: 1190, Loss: 0.675241
# Epoch: 9, Step: 1200, Loss: 0.559522
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 9, Step: 1210, Loss: 0.712209
# Epoch: 9, Step: 1220, Loss: 0.86435
# Epoch: 9, Step: 1230, Loss: 1.00616
# Epoch: 9, Step: 1240, Loss: 1.66
# Epoch: 9, Step: 1250, Loss: 0.848362
# Epoch: 9, Step: 1260, Loss: 0.555063
# Epoch: 9, Step: 1270, Loss: 0.574461
# Epoch: 9, Step: 1280, Loss: 0.587905
# Epoch: 9, Step: 1290, Loss: 0.603849
# Epoch: 9, Step: 1300, Loss: 0.754499
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# Epoch: 9, Step: 1310, Loss: 0.927365
# Epoch: 9, Step: 1320, Loss: 0.716057
# Epoch: 9, Step: 1330, Loss: 0.587585
# Epoch: 9, Step: 1340, Loss: 0.531782
# Epoch: 9, Step: 1350, Loss: 0.533003
# Model saved in file: /content/drive/My Drive/Autopilot-TensorFlow-master/Autopilot-TensorFlow-master/testing2/model5.ckpt
# Run the command line:
# --> tensorboard --logdir=./logs
# Then open http://0.0.0.0:6006/ into your web browser
